# %%
from newsapi import NewsApiClient

# %%
api = NewsApiClient(api_key="60eadef6fbff4c19b5d2f9c2aa590bfb")

# %%
all = api.get_everything(q='finance', language='en', sort_by = 'relevancy')

# %%
print(all)
type(all)
# Out:
# {'status': 'ok', 'totalResults': 27256, 'articles': [{'source': {'id': 'google-news', 'name': 'Google News'}, 'author': None, 'title': 'Spain to finance 43000 more social houses - Reuters', 'description': 'Spain to finance 43000 more social houses\xa0\xa0Reuters', 'url': 'https://consent.google.com/ml?continue=https://news.google.com/rss/articles/CBMiV2h0dHBzOi8vd3d3LnJldXRlcnMuY29tL3dvcmxkL2V1cm9wZS9zcGFpbi1maW5hbmNlLTQzMDAwLW1vcmUtc29jaWFsLWhvdXNlcy0yMDIzLTA0LTE5L9IBAA?oc%3D5&gl=FR&hl=en-US&cm=2&pc=n&src=1', 'urlToImage': None, 'publishedAt': '2023-04-19T08:21:00Z', 'content': 'We use cookies and data to<ul><li>Deliver and maintain Google services</li><li>Track outages and protect against spam, fraud, and abuse</li><li>Measure audience engagement and site statistics to unde… [+1131 chars]'}, {'source': {'id': 'google-news', 'name': 'Google News'}, 'author': None, 'title': "Uganda's junior finance minister charged with corruption offences - Reuters", 'description': "Uganda's junior 
# ...

# %%
for i in range(100):
    print(all['articles'][i])
# Out:
# {'source': {'id': 'google-news', 'name': 'Google News'}, 'author': None, 'title': 'Spain to finance 43000 more social houses - Reuters', 'description': 'Spain to finance 43000 more social houses\xa0\xa0Reuters', 'url': 'https://consent.google.com/ml?continue=https://news.google.com/rss/articles/CBMiV2h0dHBzOi8vd3d3LnJldXRlcnMuY29tL3dvcmxkL2V1cm9wZS9zcGFpbi1maW5hbmNlLTQzMDAwLW1vcmUtc29jaWFsLWhvdXNlcy0yMDIzLTA0LTE5L9IBAA?oc%3D5&gl=FR&hl=en-US&cm=2&pc=n&src=1', 'urlToImage': None, 'publishedAt': '2023-04-19T08:21:00Z', 'content': 'We use cookies and data to<ul><li>Deliver and maintain Google services</li><li>Track outages and protect against spam, fraud, and abuse</li><li>Measure audience engagement and site statistics to unde… [+1131 chars]'}
# ...
