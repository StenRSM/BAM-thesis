# %% [markdown]
# # Descriptive statistics for news data

# %%
import pandas as pd
import textstat

# %%
df_finance = pd.read_csv(r'C:\Users\Sten\Documents\EUR BAM\Thesis\data\news\finance_processed.csv')
df_sport = pd.read_csv(r'C:\Users\Sten\Documents\EUR BAM\Thesis\data\news\sport_processed.csv')
df_election = pd.read_csv(r'C:\Users\Sten\Documents\EUR BAM\Thesis\data\news\election_processed.csv')
df_general = pd.read_csv(r'C:\Users\Sten\Documents\EUR BAM\Thesis\data\news\general_processed.csv')

# %%
df_finance
# Out:
#       index                 date                   url  \
# 0         0  2023-04-18 18:30:00     blogtalkradio.com
# 1         1  2023-04-17 03:30:00           scoop.co.nz
# 2         2  2023-04-25 11:53:28       techbullion.com
# 3         3  2023-04-22 07:35:49          ghanaweb.com
# 4         4  2023-04-22 00:00:00              mdpi.com
# ...     ...                  ...                   ...
# 2602   4894  2023-05-15 20:03:05      khaleejtimes.com
# 2603   4895  2023-04-21 17:00:29        bitcoinist.com
# 2604   4896  2023-04-18 20:15:00         reliefweb.int
# 2605   4897  2023-04-20 00:00:00     globenewswire.com
# 2606   4899  2023-05-09 22:02:22  thescottishsun.co.uk
#
#                           author  \
# 0     Vernas Help Metroplex Buzz
# 1                      Find More
# 2                      Ali Bajwa
# 3                            NaN
# 4                      Yuting Tu
# ...                          ...
# 2602    Somshankar Bandyopadhyay
# ...

# %%
df_sport
# Out:
#       index                 date                    url  \
# 0         0  2023-04-28 06:00:26           usatoday.com
# 1         1  2023-04-27 08:27:48           usatoday.com
# 2         2  2023-04-28 16:55:57              yahoo.com
# 3         3  2023-04-19 12:42:05                mlb.com
# 4         4  2023-04-29 12:25:09           thehindu.com
# ...     ...                  ...                    ...
# 2976   4991  2023-04-27 14:00:26   thegatewaypundit.com
# 2977   4995  2023-04-29 19:34:32        parentology.com
# 2978   4996  2023-05-12 23:57:54  celebritiesdeaths.com
# 2979   4998  2023-04-27 19:36:18             openpr.com
# 2980   4999  2023-04-27 11:54:36          pinkvilla.com
#
#                       author  \
# 0            Alyssa Barbieri
# 1            Alyssa Barbieri
# 2             Jarrett Bailey
# 3                        NaN
# 4             Amol Karhadkar
# ...                      ...
# 2976                Jim Hoft
# 2977           Alexis Nicols
# ...

# %%
df_election
# Out:
#       index                 date               url            author  \
# 0         0  2023-04-18 13:14:09         yahoo.com   David Montesino
# 1         1  2023-04-17 22:07:17         yahoo.com            Church
# 2         2  2023-04-20 08:30:00           msn.com   President-elect
# 3         3  2023-04-17 01:00:00    thenews.com.pk     Hassan Siddiq
# 4         4  2023-04-17 22:45:54         yahoo.com   Harrison Mantas
# ...     ...                  ...               ...               ...
# 3048   4993  2023-05-02 12:30:00           msn.com  Julie Carr Smyth
# 3049   4994  2023-04-18 12:05:00           ny1.com  Associated Press
# 3050   4995  2023-04-18 20:07:01         yahoo.com         Ryan Bort
# 3051   4998  2023-04-25 14:00:00          mg.co.za     Ismail Joosub
# 3052   4999  2023-04-20 09:18:20  timesnownews.com           Shivani
#
#                                                   title topic  \
# 0     Heider Garcia stepped down as county elections...  news
# ...

# %% [markdown]
# ## Statistics

# %%
df_finance['date'] = pd.to_datetime(df_finance['date'])
df_sport['date'] = pd.to_datetime(df_sport['date'])
df_election['date'] = pd.to_datetime(df_election['date'])

# %%
df_finance['url'].value_counts()
# Out:
# yahoo.com                172
# zawya.com                 63
# reliefweb.int             52
# einnews.com               50
# indiatimes.com            39
#                         ...
# dailyhodl.com              1
# federalwaymirror.com       1
# dazeinfo.com               1
# thenews-chronicle.com      1
# thescottishsun.co.uk       1
# Name: url, Length: 817, dtype: int64

# %%
df_finance['word_count'] = df_finance['summary'].str.split().str.len()
df_finance['flesch_kincaid'] = df_finance['summary'].apply(textstat.flesch_reading_ease)

df_sport['word_count'] = df_sport['summary'].str.split().str.len()
df_sport['flesch_kincaid'] = df_sport['summary'].apply(textstat.flesch_reading_ease)

df_election['word_count'] = df_election['summary'].str.split().str.len()
df_election['flesch_kincaid'] = df_election['summary'].apply(textstat.flesch_reading_ease)

df_general['word_count'] = df_general['summary'].str.split().str.len()
df_general['flesch_kincaid'] = df_general['summary'].apply(textstat.flesch_reading_ease)

# %%
df_general[['word_count', 'flesch_kincaid']].describe()
# Out:
#         word_count  flesch_kincaid
# count  7345.000000     7345.000000
# mean     95.280871       46.228471
# std      13.292245       22.006553
# min      56.000000      -89.930000
# 25%      87.000000       35.310000
# 50%      94.000000       49.490000
# 75%     103.000000       61.400000
# max     181.000000       93.540000

# %%
df_finance['date'].min()
#df_finance['date'].max()
# Out:
# Timestamp('2023-04-16 13:33:00')

# %%
df_election['url'].value_counts()
# Out:
# msn.com                        92
# yahoo.com                      91
# manchestereveningnews.co.uk    61
# headtopics.com                 49
# legit.ng                       48
#                                ..
# fox26houston.com                1
# nationthailand.com              1
# leftfootforward.org             1
# wwaytv3.com                     1
# mg.co.za                        1
# Name: url, Length: 783, dtype: int64

# %%
df_finance['url'].value_counts()
# Out:
# yahoo.com                172
# zawya.com                 63
# reliefweb.int             52
# einnews.com               50
# indiatimes.com            39
#                         ...
# dailyhodl.com              1
# federalwaymirror.com       1
# dazeinfo.com               1
# thenews-chronicle.com      1
# thescottishsun.co.uk       1
# Name: url, Length: 817, dtype: int64

# %%
df_sport['url'].value_counts()
# Out:
# yahoo.com              220
# usatoday.com           180
# openpr.com             124
# bolavip.com             65
# skysports.com           58
#                       ...
# post-journal.com         1
# mercurynews.com          1
# timeslive.co.za          1
# ahmedabadmirror.com      1
# pinkvilla.com            1
# Name: url, Length: 910, dtype: int64

# %%
df_general['url'].value_counts()
# Out:
# yahoo.com                   1450
# msn.com                     1183
# mdpi.com                    1053
# dailymail.co.uk              357
# indiatimes.com               258
#                             ...
# denverpost.com                 1
# esa.int                        1
# nba.com                        1
# theregister.com                1
# sandiegouniontribune.com       1
# Name: url, Length: 227, dtype: int64

# %% [markdown]
# ## older news data

# %%
df_old = pd.read_csv(r'C:\Users\Sten\Documents\EUR BAM\Thesis\data\old_news\old_news_processed.csv')

# %%
df_old
# Out:
#         Unnamed: 0  class                                              title  \
# 0                0      3  Carlyle Looks Toward Commercial Aerospace (Reu...
# 1                1      3    Oil and Economy Cloud Stocks' Outlook (Reuters)
# 2                2      3  Iraq Halts Oil Exports from Main Southern Pipe...
# 3                3      3  Oil prices soar to all-time record, posing new...
# 4                4      3        Stocks End Up, But Near Year Lows (Reuters)
# ...            ...    ...                                                ...
# 119994      119994      1  Pakistan's Musharraf Says Won't Quit as Army C...
# 119995      119995      2                  Renteria signing a top-shelf deal
# 119996      119996      2                    Saban not going to Dolphins yet
# 119997      119997      2                                  Today's NFL games
# 119998      119998      2                       Nets get Carter from Raptors
#
# ...

# %%
df_old['word_count'] = df_old['text'].str.split().str.len()
df_old['flesch_kincaid'] = df_old['text'].apply(textstat.flesch_reading_ease)

# %%
df_old[['word_count', 'flesch_kincaid']].describe().to_clipboard()

# %% [markdown]
# ## GPT 3 and 4 statistics

# %%
df_gpt3 = pd.read_csv(r'C:\Users\Sten\Documents\EUR BAM\Thesis\data\ChatGPT\gpt_3_processed.csv')
df_gpt4 = pd.read_csv(r'C:\Users\Sten\Documents\EUR BAM\Thesis\data\ChatGPT\gpt_4_processed.csv')

# %%
df_gpt3
# Out:
#       index                                               text  label
# 0         0  Behold, a virgin shall conceive, and bear a so...      0
# 1         1  John Fetterman, center, the mayor of Braddock,...      0
# 2         2  Who is Alec Torelli?\n\nAlec Torelli has a uni...      0
# 3         3  The year is 2084. If you somehow survived the ...      0
# 4         4  AUSTIN, United States — "Rejections." That's w...      0
# ...     ...                                                ...    ...
# 1197    596  An environmental organization launches a globa...      1
# 1198    597  A virtual reality education platform transform...      1
# 1199    598  Countries collaborate to address a regional pu...      1
# 1200    599  The film industry celebrates diverse represent...      1
# 1201    600  Health authorities approve a groundbreaking ge...      1
#
# [1202 rows x 3 columns]

# %%
df_gpt3['word_count'] = df_gpt3['text'].str.split().str.len()
df_gpt3['flesch_kincaid'] = df_gpt3['text'].apply(textstat.flesch_reading_ease)
df_gpt4['word_count'] = df_gpt4['text'].str.split().str.len()
df_gpt4['flesch_kincaid'] = df_gpt4['text'].apply(textstat.flesch_reading_ease)

# %%
df_gpt4[['word_count', 'flesch_kincaid']].describe().to_clipboard()
